# %%
# %sql
-- Define o catalog e schema
use catalog MVP_gastos_publicos;
use schema bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# lendo o arquivo csv de 2024 com a indicaçao do separador ;
df_2024 = spark.read.format("csv").options(
    header=True,
    sep=";"
).load("/Volumes/MVP_gastos_publicos/staging/dados_gastos_publicos/gastos2024.csv")

# E lendo o arquivo CSV de 2025 tambem com a indicaçao do separador ;
df_2025 = spark.read.format("csv").options(
    header=True,
    sep=";"
).load("/Volumes/MVP_gastos_publicos/staging/dados_gastos_publicos/gastos2025.csv")

# Unindo os dois dataframes
df_bronze = df_2024.union(df_2025)

# Corrigindo o erro de algumas colunas que continham espaços a mais
# Para isso precisei remover os espaços usando .strip() no nome de cada coluna e renomear elas
new_columns = []
for col in df_bronze.columns:
    new_columns.append(col.strip()) 
df_bronze = df_bronze.toDF(*new_columns)

# Visualizar
display(df_bronze)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_ANO</th><th>ID_MES</th><th>MES_LANCAMENTO</th><th>ORGAO_CODIGO</th><th>ORGAO_DESCRICAO</th><th>UNIDADE_ORCAMENTARIA_CODIGO</th><th>UNIDADE_ORCAMENTARIA_DESCRICAO</th><th>CO_FONTE_RECURSO</th><th>NO_FONTE_RECURSO</th><th>ID_GRUPO_DESPESA_NADE</th><th>NO_GRUPO_DESPESA_NADE</th><th>CO_MOAP_NADE</th><th>NO_MOAP_NADE</th><th>ID_IN_RESULTADO_EOF</th><th>NO_IN_RESULTADO_EOF</th><th>ID_IN_TP_CREDITO_CEOR</th><th>NO_IN_TP_CREDITO_CEOR</th><th>ID_FUNCAO_PT</th><th>NO_FUNCAO_PT</th><th>ID_SUBFUNCAO_PT</th><th>NO_SUBFUNCAO_PT</th><th>ID_PROGRAMA_PT</th><th>NO_PROGRAMA_PT</th><th>ACAO</th><th>NO_ACAO</th><th>SALDO_PLOA</th><th>DOTACAO_INICIAL</th><th>DOTACAO_ATUALIZADA</th><th>DESPESAS_EMPENHADAS</th><th>DESPESAS_LIQUIDADAS</th><th>DESPESAS_PAGAS</th><th>RESTOS_A_PAGAR_PAGOS</th><th>PAGAMENTOS_TOTAIS</th><th>Poder_Orgao</th><th>Primaria_Financeira</th><th>Categoria_LC200</th><th>Categoria_RTN</th></tr></thead><tbody><tr><td>2024</td><td>1</td><td>JAN/2024</td><td>1000</td><td>CAMARA DOS DEPUTADOS</td><td>1101</td><td>CAMARA DOS DEPUTADOS</td><td>0</td><td>RECURSOS LIVRES DA UNIAO</td><td>4</td><td>INVESTIMENTOS</td><td>90</td><td>APLICACOES DIRETAS</td><td>1</td><td>PRIMARIO OBRIGATORIO</td><td>A</td><td>INICIAL (LOA)</td><td>1</td><td>LEGISLATIVA</td><td>331</td><td>PROTECAO E BENEFICIOS AO TRABALHADOR</td><td>34</td><td>PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGISLATIVO</td><td>2004</td><td>ASSISTENCIA MEDICA E ODONTOLOGICA AOS SERVIDORES CIVIS, EMPR</td><td> 1.695.000,00 </td><td> 1.695.000,00 </td><td> 1.695.000,00 </td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>CD</td><td>Prim�ria</td><td>Despesa sujeita: Legislativo, Judici�rio, MPU e DPU</td><td>2.3.12 - Legislativo, Judici�rio, MPU e DPU</td></tr><tr><td>2024</td><td>1</td><td>JAN/2024</td><td>1000</td><td>CAMARA DOS DEPUTADOS</td><td>1101</td><td>CAMARA DOS DEPUTADOS</td><td>0</td><td>RECURSOS LIVRES DA UNIAO</td><td>4</td><td>INVESTIMENTOS</td><td>90</td><td>APLICACOES DIRETAS</td><td>1</td><td>PRIMARIO OBRIGATORIO</td><td>X</td><td>RP INICIAL (LOA)</td><td>1</td><td>LEGISLATIVA</td><td>331</td><td>PROTECAO E BENEFICIOS AO TRABALHADOR</td><td>34</td><td>PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGISLATIVO</td><td>2004</td><td>ASSISTENCIA MEDICA E ODONTOLOGICA AOS SERVIDORES CIVIS, EMPR</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td> 225,00 </td><td> 225,00 </td><td>CD</td><td>Prim�ria</td><td>Despesa sujeita: Legislativo, Judici�rio, MPU e DPU</td><td>2.3.12 - Legislativo, Judici�rio, MPU e DPU</td></tr><tr><td>2024</td><td>1</td><td>JAN/2024</td><td>1000</td><td>CAMARA DOS DEPUTADOS</td><td>1101</td><td>CAMARA DOS DEPUTADOS</td><td>0</td><td>RECURSOS LIVRES DA UNIAO</td><td>4</td><td>INVESTIMENTOS</td><td>90</td><td>APLICACOES DIRETAS</td><td>2</td><td>PRIMARIO DISCRICIONARIO</td><td>A</td><td>INICIAL (LOA)</td><td>1</td><td>LEGISLATIVA</td><td>31</td><td>ACAO LEGISLATIVA</td><td>34</td><td>PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGISLATIVO</td><td>4061</td><td>PROCESSO LEGISLATIVO, FISCALIZACAO E REPRESENTACAO POLITICA</td><td> 126.637.219,00 </td><td> 126.637.219,00 </td><td> 126.637.219,00 </td><td> 15.828.976,60 </td><td>null</td><td>null</td><td>null</td><td>null</td><td>CD</td><td>Prim�ria</td><td>Despesa sujeita: Legislativo, Judici�rio, MPU e DPU</td><td>2.3.12 - Legislativo, Judici�rio, MPU e DPU</td></tr><tr><td>2024</td><td>1</td><td>JAN/2024</td><td>1000</td><td>CAMARA DOS DEPUTADOS</td><td>1101</td><td>CAMARA DOS DEPUTADOS</td><td>0</td><td>RECURSOS LIVRES DA UNIAO</td><td>4</td><td>INVESTIMENTOS</td><td>90</td><td>APLICACOES DIRETAS</td><td>2</td><td>PRIMARIO DISCRICIONARIO</td><td>A</td><td>INICIAL (LOA)</td><td>1</td><td>LEGISLATIVA</td><td>122</td><td>ADMINISTRACAO GERAL</td><td>34</td><td>PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGISLATIVO</td><td>10S2</td><td>CONSTRUCAO D ...

# %%
# salvando dataframe como tabela no Unity Catalog
df_bronze.write.format("delta").mode("overwrite").saveAsTable("MVP_gastos_publicos.bronze.gastos_publicos")

# %%
# %sql
-- Adicionar descricao na tabela
COMMENT ON TABLE MVP_gastos_publicos.bronze.gastos_publicos IS 'Dados brutos de gastos publicos federais (2024-2025)';

-- Adicionar descricoes nas colunas principais
COMMENT ON COLUMN MVP_gastos_publicos.bronze.gastos_publicos.ID_ANO IS 'Ano da despesa';
COMMENT ON COLUMN MVP_gastos_publicos.bronze.gastos_publicos.ID_MES IS 'Mes da despesa';
COMMENT ON COLUMN MVP_gastos_publicos.bronze.gastos_publicos.ORGAO_DESCRICAO IS 'Nome do orgao';
COMMENT ON COLUMN MVP_gastos_publicos.bronze.gastos_publicos.PAGAMENTOS_TOTAIS IS 'Valor total pago';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE MVP_gastos_publicos.bronze.gastos_publicos;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>ID_ANO</td><td>string</td><td>Ano da despesa</td></tr><tr><td>ID_MES</td><td>string</td><td>Mes da despesa</td></tr><tr><td>MES_LANCAMENTO</td><td>string</td><td>null</td></tr><tr><td>ORGAO_CODIGO</td><td>string</td><td>null</td></tr><tr><td>ORGAO_DESCRICAO</td><td>string</td><td>Nome do orgao</td></tr><tr><td>UNIDADE_ORCAMENTARIA_CODIGO</td><td>string</td><td>null</td></tr><tr><td>UNIDADE_ORCAMENTARIA_DESCRICAO</td><td>string</td><td>null</td></tr><tr><td>CO_FONTE_RECURSO</td><td>string</td><td>null</td></tr><tr><td>NO_FONTE_RECURSO</td><td>string</td><td>null</td></tr><tr><td>ID_GRUPO_DESPESA_NADE</td><td>string</td><td>null</td></tr><tr><td>NO_GRUPO_DESPESA_NADE</td><td>string</td><td>null</td></tr><tr><td>CO_MOAP_NADE</td><td>string</td><td>null</td></tr><tr><td>NO_MOAP_NADE</td><td>string</td><td>null</td></tr><tr><td>ID_IN_RESULTADO_EOF</td><td>string</td><td>null</td></tr><tr><td>NO_IN_RESULTADO_EOF</td><td>string</td><td>null</td></tr><tr><td>ID_IN_TP_CREDITO_CEOR</td><td>string</td><td>null</td></tr><tr><td>NO_IN_TP_CREDITO_CEOR</td><td>string</td><td>null</td></tr><tr><td>ID_FUNCAO_PT</td><td>string</td><td>null</td></tr><tr><td>NO_FUNCAO_PT</td><td>string</td><td>null</td></tr><tr><td>ID_SUBFUNCAO_PT</td><td>string</td><td>null</td></tr><tr><td>NO_SUBFUNCAO_PT</td><td>string</td><td>null</td></tr><tr><td>ID_PROGRAMA_PT</td><td>string</td><td>null</td></tr><tr><td>NO_PROGRAMA_PT</td><td>string</td><td>null</td></tr><tr><td>ACAO</td><td>string</td><td>null</td></tr><tr><td>NO_ACAO</td><td>string</td><td>null</td></tr><tr><td>SALDO_PLOA</td><td>string</td><td>null</td></tr><tr><td>DOTACAO_INICIAL</td><td>string</td><td>null</td></tr><tr><td>DOTACAO_ATUALIZADA</td><td>string</td><td>null</td></tr><tr><td>DESPESAS_EMPENHADAS</td><td>string</td><td>null</td></tr><tr><td>DESPESAS_LIQUIDADAS</td><td>string</td><td>null</td></tr><tr><td>DESPESAS_PAGAS</td><td>string</td><td>null</td></tr><tr><td>RESTOS_A_PAGAR_PAGOS</td><td>string</td><td>null</td></tr><tr><td>PAGAMENTOS_TOTAIS</td><td>string</td><td>Valor total pago</td></tr><tr><td>Poder_Orgao</td><td>string</td><td>null</td></tr><tr><td>Primaria_Financeira</td><td>string</td><td>null</td></tr><tr><td>Categoria_LC200</td><td>string</td><td>null</td></tr><tr><td>Categoria_RTN</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM MVP_gastos_publicos.bronze.gastos_publicos LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_ANO</th><th>ID_MES</th><th>MES_LANCAMENTO</th><th>ORGAO_CODIGO</th><th>ORGAO_DESCRICAO</th><th>UNIDADE_ORCAMENTARIA_CODIGO</th><th>UNIDADE_ORCAMENTARIA_DESCRICAO</th><th>CO_FONTE_RECURSO</th><th>NO_FONTE_RECURSO</th><th>ID_GRUPO_DESPESA_NADE</th><th>NO_GRUPO_DESPESA_NADE</th><th>CO_MOAP_NADE</th><th>NO_MOAP_NADE</th><th>ID_IN_RESULTADO_EOF</th><th>NO_IN_RESULTADO_EOF</th><th>ID_IN_TP_CREDITO_CEOR</th><th>NO_IN_TP_CREDITO_CEOR</th><th>ID_FUNCAO_PT</th><th>NO_FUNCAO_PT</th><th>ID_SUBFUNCAO_PT</th><th>NO_SUBFUNCAO_PT</th><th>ID_PROGRAMA_PT</th><th>NO_PROGRAMA_PT</th><th>ACAO</th><th>NO_ACAO</th><th>SALDO_PLOA</th><th>DOTACAO_INICIAL</th><th>DOTACAO_ATUALIZADA</th><th>DESPESAS_EMPENHADAS</th><th>DESPESAS_LIQUIDADAS</th><th>DESPESAS_PAGAS</th><th>RESTOS_A_PAGAR_PAGOS</th><th>PAGAMENTOS_TOTAIS</th><th>Poder_Orgao</th><th>Primaria_Financeira</th><th>Categoria_LC200</th><th>Categoria_RTN</th></tr></thead><tbody><tr><td>2024</td><td>1</td><td>JAN/2024</td><td>1000</td><td>CAMARA DOS DEPUTADOS</td><td>1101</td><td>CAMARA DOS DEPUTADOS</td><td>0</td><td>RECURSOS LIVRES DA UNIAO</td><td>4</td><td>INVESTIMENTOS</td><td>90</td><td>APLICACOES DIRETAS</td><td>1</td><td>PRIMARIO OBRIGATORIO</td><td>A</td><td>INICIAL (LOA)</td><td>1</td><td>LEGISLATIVA</td><td>331</td><td>PROTECAO E BENEFICIOS AO TRABALHADOR</td><td>34</td><td>PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGISLATIVO</td><td>2004</td><td>ASSISTENCIA MEDICA E ODONTOLOGICA AOS SERVIDORES CIVIS, EMPR</td><td> 1.695.000,00 </td><td> 1.695.000,00 </td><td> 1.695.000,00 </td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>CD</td><td>Prim�ria</td><td>Despesa sujeita: Legislativo, Judici�rio, MPU e DPU</td><td>2.3.12 - Legislativo, Judici�rio, MPU e DPU</td></tr><tr><td>2024</td><td>1</td><td>JAN/2024</td><td>1000</td><td>CAMARA DOS DEPUTADOS</td><td>1101</td><td>CAMARA DOS DEPUTADOS</td><td>0</td><td>RECURSOS LIVRES DA UNIAO</td><td>4</td><td>INVESTIMENTOS</td><td>90</td><td>APLICACOES DIRETAS</td><td>1</td><td>PRIMARIO OBRIGATORIO</td><td>X</td><td>RP INICIAL (LOA)</td><td>1</td><td>LEGISLATIVA</td><td>331</td><td>PROTECAO E BENEFICIOS AO TRABALHADOR</td><td>34</td><td>PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGISLATIVO</td><td>2004</td><td>ASSISTENCIA MEDICA E ODONTOLOGICA AOS SERVIDORES CIVIS, EMPR</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td> 225,00 </td><td> 225,00 </td><td>CD</td><td>Prim�ria</td><td>Despesa sujeita: Legislativo, Judici�rio, MPU e DPU</td><td>2.3.12 - Legislativo, Judici�rio, MPU e DPU</td></tr><tr><td>2024</td><td>1</td><td>JAN/2024</td><td>1000</td><td>CAMARA DOS DEPUTADOS</td><td>1101</td><td>CAMARA DOS DEPUTADOS</td><td>0</td><td>RECURSOS LIVRES DA UNIAO</td><td>4</td><td>INVESTIMENTOS</td><td>90</td><td>APLICACOES DIRETAS</td><td>2</td><td>PRIMARIO DISCRICIONARIO</td><td>A</td><td>INICIAL (LOA)</td><td>1</td><td>LEGISLATIVA</td><td>31</td><td>ACAO LEGISLATIVA</td><td>34</td><td>PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGISLATIVO</td><td>4061</td><td>PROCESSO LEGISLATIVO, FISCALIZACAO E REPRESENTACAO POLITICA</td><td> 126.637.219,00 </td><td> 126.637.219,00 </td><td> 126.637.219,00 </td><td> 15.828.976,60 </td><td>null</td><td>null</td><td>null</td><td>null</td><td>CD</td><td>Prim�ria</td><td>Despesa sujeita: Legislativo, Judici�rio, MPU e DPU</td><td>2.3.12 - Legislativo, Judici�rio, MPU e DPU</td></tr><tr><td>2024</td><td>1</td><td>JAN/2024</td><td>1000</td><td>CAMARA DOS DEPUTADOS</td><td>1101</td><td>CAMARA DOS DEPUTADOS</td><td>0</td><td>RECURSOS LIVRES DA UNIAO</td><td>4</td><td>INVESTIMENTOS</td><td>90</td><td>APLICACOES DIRETAS</td><td>2</td><td>PRIMARIO DISCRICIONARIO</td><td>A</td><td>INICIAL (LOA)</td><td>1</td><td>LEGISLATIVA</td><td>122</td><td>ADMINISTRACAO GERAL</td><td>34</td><td>PROGRAMA DE GESTAO E MANUTENCAO DO PODER LEGISLATIVO</td><td>10S2</td><td>CONSTRUCAO D ...
