# %%
# %sql
-- selecionar o catalogo e schema 
use catalog MVP_gastos_publicos;
use schema staging;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
--criar o volume para os dados 
create volume if not exists dados_gastos_publicos
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
show volumes in MVP_gastos_publicos.staging;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>volume_name</th></tr></thead><tbody><tr><td>staging</td><td>dados_gastos_publicos</td></tr></tbody></table></div>

# %% [markdown]
# # Dados
#
# **Fonte:** Portal da Transparência do Governo Federal
#
# **URL:** https://portaldatransparencia.gov.br/download-de-dados/despesas
#
# **Período:** 2024 e 2025
#
# **Formato:** CSV (separador ;)
#
# **Tamanho total:** 220 MB (3 arquivos + metadados)
